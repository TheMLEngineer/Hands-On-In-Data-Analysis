# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Import dataset

# %%
df = pd.read_csv('Population.csv')

# %%
df.head()
# Out:
#    Zip Code  Total Population  Median Age  Total Males  Total Females  \
# 0     91371                 1        73.5            0              1
# 1     90001             57110        26.6        28468          28642
# 2     90002             51223        25.5        24876          26347
# 3     90003             66266        26.3        32631          33635
# 4     90004             62180        34.8        31302          30878
#
#    Total Households  Average Household Size
# 0                 1                    1.00
# 1             12971                    4.40
# 2             11731                    4.36
# 3             15642                    4.22
# 4             22547                    2.73

# %%
df.shape
# Out:
# (319, 7)

# %%
df.dropna()
# Out:
#      Zip Code  Total Population  Median Age  Total Males  Total Females  \
# 0       91371                 1        73.5            0              1
# 1       90001             57110        26.6        28468          28642
# 2       90002             51223        25.5        24876          26347
# 3       90003             66266        26.3        32631          33635
# 4       90004             62180        34.8        31302          30878
# 5       90005             37681        33.9        19299          18382
# 6       90006             59185        32.4        30254          28931
# 7       90007             40920        24.0        20915          20005
# 8       90008             32327        39.7        14477          17850
# 9       90010              3800        37.8         1874           1926
# 10      90011            103892        26.2        52794          51098
# 11      90012             31103        36.3        19493          11610
# ...

# %%
df.shape
# Out:
# (319, 7)

# %%
df.plot()

# %%
approx_population = round(df['Total Population'].mean())

# %% [markdown]
# ## Get specific col as a data frame

# %%
df1 = pd.read_csv('Population.csv',usecols = ['Zip Code'],squeeze = True)

# %%
df1.head()
# Out:
# 0    91371
# 1    90001
# 2    90002
# 3    90003
# 4    90004
# Name: Zip Code, dtype: int64

# %%
df1.sort_values()
#Have to add squeeze parameter while reading the data to use this sort values function
# Out:
# 1      90001
# 2      90002
# 3      90003
# 4      90004
# 5      90005
# 6      90006
# 7      90007
# 8      90008
# 9      90010
# 10     90011
# 11     90012
# 12     90013
# 13     90014
# 14     90015
# 15     90016
# 16     90017
# 17     90018
# 18     90019
# 19     90020
# 20     90021
# 21     90022
# 22     90023
# 23     90024
# 24     90025
# 25     90026
# 26     90027
# 27     90028
# 28     90029
# 29     90031
# 30     90032
#        ...
# 289    91792
# 290    91801
# 291    91803
# 292    92301
# 293    92371
# 294    92372
# 295    92397
# 296    92821
# 297    92823
# 298    92833
# 299    93040
# 300    93063
# 301    93225
# 302    93243
# 303    93252
# 304    93510
# 305    93523
# 306    93532
# 307    93534
# 308    93535
# 309    93536
# 310    93543
# 311    93544
# 312    93550
# 313    93551
# 314    93552
# 315    93553
# 316    93560
# 317    93563
# 318    93591
# Name: Zip Code, Length: 319, dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=319, step=1)

# %%
df.values
# Out:
# array([[9.1371e+04, 1.0000e+00, 7.3500e+01, ..., 1.0000e+00, 1.0000e+00,
#         1.0000e+00],
#        [9.0001e+04, 5.7110e+04, 2.6600e+01, ..., 2.8642e+04, 1.2971e+04,
#         4.4000e+00],
#        [9.0002e+04, 5.1223e+04, 2.5500e+01, ..., 2.6347e+04, 1.1731e+04,
#         4.3600e+00],
#        ...,
#        [9.3560e+04, 1.8910e+04, 3.2400e+01, ..., 9.4190e+03, 6.4690e+03,
#         2.9200e+00],
#        [9.3563e+04, 3.8800e+02, 4.4500e+01, ..., 1.2500e+02, 1.0300e+02,
#         2.5300e+00],
#        [9.3591e+04, 7.2850e+03, 3.0900e+01, ..., 3.6320e+03, 1.9820e+03,
#         3.6700e+00]])

# %%
df.tail()
# Out:
#      Zip Code  Total Population  Median Age  Total Males  Total Females  \
# 314     93552             38158        28.4        18711          19447
# 315     93553              2138        43.3         1121           1017
# 316     93560             18910        32.4         9491           9419
# 317     93563               388        44.5          263            125
# 318     93591              7285        30.9         3653           3632
#
#      Total Households  Average Household Size
# 314              9690                    3.93
# 315               816                    2.62
# 316              6469                    2.92
# 317               103                    2.53
# 318              1982                    3.67

# %%
df.shape
# Out:
# (319, 7)

# %%
df.dtypes
# Out:
# Zip Code                    int64
# Total Population            int64
# Median Age                float64
# Total Males                 int64
# Total Females               int64
# Total Households            int64
# Average Household Size    float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Zip Code', 'Total Population', 'Median Age', 'Total Males',
#        'Total Females', 'Total Households', 'Average Household Size'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319 entries, 0 to 318
# Data columns (total 7 columns):
# Zip Code                  319 non-null int64
# Total Population          319 non-null int64
# Median Age                319 non-null float64
# Total Males               319 non-null int64
# Total Females             319 non-null int64
# Total Households          319 non-null int64
# Average Household Size    319 non-null float64
# dtypes: float64(2), int64(5)
# memory usage: 17.5 KB

# %%
df_specific_cols = pd.read_csv('Population.csv',usecols = ['Zip Code','Total Population','Total Males','Total Females'],squeeze = True)

# %%
df_specific_cols.head()
# Out:
#    Zip Code  Total Population  Total Males  Total Females
# 0     91371                 1            0              1
# 1     90001             57110        28468          28642
# 2     90002             51223        24876          26347
# 3     90003             66266        32631          33635
# 4     90004             62180        31302          30878

# %%
df_specific_cols.sum(axis=1)
#Sum of all number elements in a row 
#axis = 1 means columns
# Out:
# 0       91373
# 1      204221
# 2      192448
# 3      222535
# 4      214364
# 5      165367
# 6      208376
# 7      171847
# 8      154662
# 9       97610
# 10     297795
# 11     152218
# 12     113557
# 13     104024
# 14     127987
# 15     185208
# 16     137553
# 17     188638
# 18     218935
# 19     167954
# 20      97923
# 21     224380
# 22     181829
# 23     184928
# 24     174319
# 25     225764
# 26     180329
# 27     147456
# 28     167263
# 29     168663
#         ...
# 289    153500
# 290    197271
# 291    152447
# 292    157751
# 293    125897
# 294    104812
# 295    102185
# 296    163887
# 297    100049
# 298    196367
# 299     97102
# 300    201795
# 301    103379
# 302     96641
# 303    101604
# 304    109496
# 305     99671
# 306     99396
# 307    172216
# 308    237627
# 309    235372
# 310    119609
# 311     96062
# 312    243408
# 313    195147
# 314    169868
# 315     97829
# 316    131380
# 317     94339
# 318    108161
# ...

# %%
df['Total Males'][2] = 2020
# Out:
# C:\Users\kmuthu2\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df.head()
#The index 2 and element in the column Total males is changed to 2020
# Out:
#    Zip Code  Total Population  Median Age  Total Males  Total Females  \
# 0     91371                 1        73.5            0              1
# 1     90001             57110        26.6        28468          28642
# 2     90002             51223        25.5         2020          26347
# 3     90003             66266        26.3        32631          33635
# 4     90004             62180        34.8        31302          30878
#
#    Total Households  Average Household Size
# 0                 1                    1.00
# 1             12971                    4.40
# 2             11731                    4.36
# 3             15642                    4.22
# 4             22547                    2.73

# %%
df['Country'] = 'USA'
# To add new col to whole df

# %%
df.head()
# Out:
#    Zip Code  Total Population  Median Age  Total Males  Total Females  \
# 0     91371                 1        73.5            0              1
# 1     90001             57110        26.6        28468          28642
# 2     90002             51223        25.5         2020          26347
# 3     90003             66266        26.3        32631          33635
# 4     90004             62180        34.8        31302          30878
#
#    Total Households  Average Household Size Country
# 0                 1                    1.00     USA
# 1             12971                    4.40     USA
# 2             11731                    4.36     USA
# 3             15642                    4.22     USA
# 4             22547                    2.73     USA

# %%
df['Median Age'] = df['Median Age'] + 5
#Whole col value is changed

# %%
df.head()
# Out:
#    Zip Code  Total Population  Median Age  Total Males  Total Females  \
# 0     91371                 1        78.5            0              1
# 1     90001             57110        31.6        28468          28642
# 2     90002             51223        30.5         2020          26347
# 3     90003             66266        31.3        32631          33635
# 4     90004             62180        39.8        31302          30878
#
#    Total Households  Average Household Size Country
# 0                 1                    1.00     USA
# 1             12971                    4.40     USA
# 2             11731                    4.36     USA
# 3             15642                    4.22     USA
# 4             22547                    2.73     USA

# %%
df['Median Age'] = df['Median Age'].astype('int')
#Float is converted to int

# %%
df.head()
# Out:
#    Zip Code  Total Population  Median Age  Total Males  Total Females  \
# 0     91371                 1          78            0              1
# 1     90001             57110          31        28468          28642
# 2     90002             51223          30         2020          26347
# 3     90003             66266          31        32631          33635
# 4     90004             62180          39        31302          30878
#
#    Total Households  Average Household Size Country
# 0                 1                    1.00     USA
# 1             12971                    4.40     USA
# 2             11731                    4.36     USA
# 3             15642                    4.22     USA
# 4             22547                    2.73     USA

# %%
df['Median Age'].nunique()
#Gives unique ages (after conerting to int)
# Out:
# 37

# %%
df.sort_values('Average Household Size',inplace=True)
#Change Average Household Size col to ascending and taking tat as reference change whole df

# %%
df.head()
# Out:
#      Zip Code  Total Population  Median Age  Total Males  Total Females  \
# 90      90263              1612          24          665            947
# 153     90747                 0           5            0              0
# 119     90506                 0           5            0              0
# 252     91608                 0           5            0              0
# 61      90071                15          50           13              2
#
#      Total Households  Average Household Size Country
# 90                  0                     0.0     USA
# 153                 0                     0.0     USA
# 119                 0                     0.0     USA
# 252                 0                     0.0     USA
# 61                  0                     0.0     USA
